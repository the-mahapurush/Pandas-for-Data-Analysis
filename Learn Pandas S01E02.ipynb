# %% [markdown]
# ## Welcome to Episode 2 of Learn Pandas Series
# * Recap of Episode 1
# * Sorting
# * Filtering

# %%
import pandas as pd

# %%
# Creating a small dataframe to learn then we will apply the concept on large dataset
dict1={
 'First Name':['Ritesh','Muggu','Alex','Rocky','Md'],"Last Name":['Stark','Babe','Hales','Bhai','Hales'], 'Designation':['CEO','MD','HR','SE','JE'],'Age':[25,25,27,31,34]
}

# %%
df=pd.DataFrame(dict1)

# %%
dataset_so=pd.read_csv('survey_results_public.csv', index_col='ResponseId') #index_col is used to make a col as default
dataset_survey=pd.read_csv('survey_results_schema.csv')

# %% [markdown]
# ## RECAP
# ### Indexing a particular column
# ``dataframe_name.set_index('col_name', inplace=True)``
# <br>``inplace=True`` is used to make chnages in original dataframe

# %%
dataset_so
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 83435                          I am a developer by profession
# 83436                          I am a developer by profession
# 83437                          I am a developer by profession
# 83438                          I am a developer by profession
# 83439                          I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Student, full-time
# ...

# %%
dataset_survey
# Out:
#        qid               qname  \
# 0    QID16                  S0
# 1    QID12            MetaInfo
# 2     QID1                  S1
# 3     QID2          MainBranch
# 4    QID24          Employment
# 5     QID6             Country
# 6     QID7            US_State
# 7     QID9          UK_Country
# 8   QID190                  S2
# 9    QID25             EdLevel
# 10  QID149          Age1stCode
# 11  QID276           LearnCode
# 12   QID32           YearsCode
# 13   QID34        YearsCodePro
# 14   QID31             DevType
# 15   QID29             OrgSize
# 16   QID50            Currency
# 17   QID51           CompTotal
# 18   QID52            CompFreq
# 19   QID61                  S3
# 20  QID233            Language
# 21  QID262            Database
# 22  QID263            Platform
# 23  QID264            Webframe
# 24  QID265            MiscTech
# 25  QID275           ToolsTech
# 26  QID274      NEWCollabTools
# 27   QID71               OpSys
# 28  QID243            NEWStuck
# ...

# %%
dataset_survey.set_index('qid', inplace=True)

# %%
dataset_survey
# Out:
#                      qname                                           question  \
# qid
# QID16                   S0  <div><span style="font-size:19px;"><strong>Hel...
# QID12             MetaInfo                                  Browser Meta Info
# QID1                    S1  <span style="font-size:22px; font-family: aria...
# QID2            MainBranch  Which of the following options best describes ...
# QID24           Employment  Which of the following best describes your cur...
# QID6               Country  Where do you live? <span style="font-weight: b...
# QID7              US_State  <p>In which state or territory of the USA do y...
# QID9            UK_Country  In which part of the United Kingdom do you liv...
# QID190                  S2  <span style="font-size:22px; font-family: aria...
# QID25              EdLevel  Which of the following best describes the high...
# QID149          Age1stCode  At what age did you write your first line of c...
# ...

# %%
dataset_survey.loc['QID25']
# Out:
# qname                                                   EdLevel
# question      Which of the following best describes the high...
# force_resp                                                False
# type                                                         MC
# selector                                                   SAVR
# Name: QID25, dtype: object

# %%
dataset_survey.loc['QID25','question'] #to see full text of question
# Out:
# 'Which of the following best describes the highest level of formal education that you’ve completed? *'

# %% [markdown]
# ### SORTING INDEX

# %%
dataset_survey.sort_index(inplace=True)

# %%
dataset_survey #sorted index
# Out:
#                      qname                                           question  \
# qid
# QID1                    S1  <span style="font-size:22px; font-family: aria...
# QID100         SOVisitFreq  How frequently would you say you visit Stack O...
# QID101           SOAccount              Do you have a Stack Overflow account?
# QID102          SOPartFreq  How frequently would you say you participate i...
# QID106              SOComm  Do you consider yourself a member of the Stack...
# QID12             MetaInfo                                  Browser Meta Info
# QID121                  S5  <span style="font-size:22px; font-family: aria...
# QID122              Gender  Which of the following describe you, if any? P...
# QID124       Accessibility  Which of the following describe you, if any? P...
# QID125        MentalHealth  Which of the following describe you, if any? P...
# QID126           Ethnicity  Which of the following describe you, if any? P...
# ...

# %%
#dataset_survey.reset_index()

# %%
df2=pd.DataFrame({'Gender':['M',"F","TG",'M','M']})

# %%
df2
# Out:
#   Gender
# 0      M
# 1      F
# 2     TG
# 3      M
# 4      M

# %% [markdown]
# ## FILTERING

# %%
df
# Out:
#   First Name Last Name Designation  Age
# 0     Ritesh     Stark         CEO   25
# 1      Muggu      Babe          MD   25
# 2       Alex     Hales          HR   27
# 3      Rocky      Bhai          SE   31
# 4         Md     Hales          JE   34

# %%
df["Gender"]=df2['Gender']

# %%
df.set_index("First Name", inplace=True)

# %%
df['Designation']=='CEO'
# Out:
# First Name
# Ritesh     True
# Muggu     False
# Alex      False
# Rocky     False
# Md        False
# Name: Designation, dtype: bool

# %%
df[df['Designation']=='CEO']
# Out:
#            Last Name Designation  Age Gender
# First Name
# Ritesh         Stark         CEO   25      M

# %%
filter_lastname=df['Last Name']=='Hales'

# %%
df[filter_lastname]
# Out:
#            Last Name Designation  Age Gender
# First Name
# Alex           Hales          HR   27     TG
# Md             Hales          JE   34      M

# %%
df.loc[filter_lastname,'Gender'] #we can use loc as well
# Out:
# First Name
# Alex    TG
# Md       M
# Name: Gender, dtype: object
